# %% [markdown]
# # Name :- Otaradi Vijay
# # Enrollment No :- 22SOEIT11020
# # Roll No :- 18
# # Div ( IT -A )
#
# #Tutorial - 03

# %% [markdown]
# #Tutorial 3:
#
# Visualize Data Using Matplotlib and Seaborn Library
#
# **Description**: Create visualizations with Matplotlib and Seaborn.
#
# **Dataset**: Clean_Dataset
#
# **Task**: Create various plots (e.g., histograms, scatter plots, box plots) to visualize the data.
#
# 1.Import numpy, pandas, seaborn and matplotlib library.
#
# 2.Download data set from kaggle : Flight Price Prediction (kaggle.com) https://www.kaggle.com/datasets/shubhambathwal/flight-price-prediction/
#
# 3.Read dataset “Clean_Dataset”.
#
# 4.Find Out columns.
#
# 5.Rename columns Unnamed: 0'  to 'id'.
#
# 6.Are there any null values in the dataset?
#
# 7.Find categories of ‘source_city’. (categorical data)
#
# 8.Find categories of ‘class’. (categorical data)
#
# 9.Draw Count plot for ‘source_city’.
#
# 10.Draw Count plot for ‘class’.
#
# 11.Draw a pie plot for ‘source_city’.
#
# 12.Draw Donut plot for ‘source_city’.
#
# 13.Draw Histogram plot for ‘price’.
#
# 14.Draw Distplot for ‘price’

# %%
#1.
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#2.
from google.colab import drive
drive.mount('/content/drive')

# %%
#3.
clean=pd.read_csv('/content/drive/MyDrive/SEM 06/Clean_Dataset.csv')
clean

# %%
#4.
clean.columns

# %%
#5.
clean=clean.rename(columns={'Unnamed: 0':'id'})

# %%
#6.
# clean.iloc[0]
clean.isnull().sum()

# %%
#7.
source_city = clean['source_city'].unique()
source_city

# %%
#8.
class_categories = clean['class'].unique()
class_categories

# %%
#9.
sns.countplot(x='source_city',data=clean)
plt.show()

# %%
#10.
sns.countplot(x='class',data=clean)
plt.show()

# %%
#11.
#clean['source_city'].value_counts().plot.pie()
clean['source_city'].value_counts().plot(kind='pie' , autopct='%.2f')

# %%
#12.
plt.pie(clean['source_city'].value_counts(),
        labels=clean['source_city'].unique(),autopct='%.2f',
        wedgeprops=dict(width=0.4
                        ))

# %%
#13.
plt.hist(clean['price'])
#clean['price'].value_counts().plot.hist()

# %%
#14.
sns.distplot(clean['price'])

# %%
#15.
sns.distplot(clean['duration'])
