# %% [markdown]
# #Name :- Otaradi Vijay
# #Enrollment No :- 22SOEIT11020
# #Roll No :- 18
# #Div ( IT -A )
# #Tutorial - 09

# %%
import numpy as np
import pandas as pd

# %%
#2.
from google.colab import drive
drive.mount('/content/drive')

# %%
#3.
user=pd.read_csv('/content/drive/MyDrive/SEM 06/users.csv')
user
